# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv(r'C:\Users\Kerry\loan_applications.csv')
df.shape
# Out:
# (50000, 21)

# %%
df.head()
# Out:
#                          application_id customer_id application_date  \
# 0  c8bf0bea-70e6-4870-9125-41b8210c527f  CUST109427         4/9/2023
# 1  91224cec-3544-4bc7-ac15-a9792da54c02  CUST106146        9/23/2023
# 2  4efcd02d-4a03-4ab7-9bd1-0ff430493d0c  CUST100674        5/22/2023
# 3  a61337d4-ba04-4a68-b492-2cb8266e6ed7  CUST106466         7/9/2024
# 4  a8d1639e-170b-41b2-826a-55c7dae38d16  CUST112319       11/20/2023
#
#         loan_type  loan_amount_requested  loan_tenure_months  \
# 0   Business Loan                 604000                  12
# 1        Car Loan                 100000                 240
# 2  Education Loan                 431000                  60
# 3        Car Loan                 324000                 120
# 4   Personal Loan                 100000                  36
#
#    interest_rate_offered     purpose_of_loan employment_status  \
# 0                  11.66   Medical Emergency           Retired
# ...

# %%
df.tail()
# Out:
#                              application_id customer_id application_date  \
# 49995  1d4b1017-e8a1-4a7b-94d1-63e90b05d665  CUST114840       12/29/2024
# 49996  2984426c-6d0b-437c-9a13-84bf3244c6d4  CUST103055        6/17/2022
# 49997  cdbc7ad8-0f23-46c4-aaca-619053ad5605  CUST119886       12/14/2024
# 49998  46a8f901-8005-4ae7-923e-f9d0dc8e0ae8  CUST109088       12/16/2022
# 49999  6aaf792e-6755-408e-a9ef-4d9bf841864b  CUST113445        3/25/2025
#
#             loan_type  loan_amount_requested  loan_tenure_months  \
# 49995  Education Loan                 381000                  24
# 49996  Education Loan                 736000                 120
# 49997        Car Loan                 436000                  12
# 49998   Business Loan                 827000                  24
# 49999       Home Loan                 100000                  24
#
#        interest_rate_offered    purpose_of_loan employment_status  \
# ...

# %%
df.isnull().sum()
# Out:
# application_id                   0
# customer_id                      0
# application_date                 0
# loan_type                        0
# loan_amount_requested            0
# loan_tenure_months               0
# interest_rate_offered            0
# purpose_of_loan                  0
# employment_status                0
# monthly_income                   0
# cibil_score                      0
# existing_emis_monthly            0
# debt_to_income_ratio             0
# property_ownership_status        0
# residential_address              0
# applicant_age                    0
# gender                           0
# number_of_dependents             0
# loan_status                      0
# fraud_flag                       0
# fraud_type                   48974
# dtype: int64

# %%
df_drop = df.drop('fraud_type', axis=1)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   application_id             50000 non-null  object
#  1   customer_id                50000 non-null  object
#  2   application_date           50000 non-null  object
#  3   loan_type                  50000 non-null  object
#  4   loan_amount_requested      50000 non-null  int64
#  5   loan_tenure_months         50000 non-null  int64
#  6   interest_rate_offered      50000 non-null  float64
#  7   purpose_of_loan            50000 non-null  object
#  8   employment_status          50000 non-null  object
#  9   monthly_income             50000 non-null  int64
#  10  cibil_score                50000 non-null  int64
#  11  existing_emis_monthly      50000 non-null  int64
#  12  debt_to_income_ratio       50000 non-null  float64
# ...

# %%
df_drop.describe()
# Out:
#        loan_amount_requested  loan_tenure_months  interest_rate_offered  \
# count           5.000000e+04          50000.0000           50000.000000
# mean            5.139130e+05            121.3884              10.528547
# std             2.752126e+05            121.4104               1.926442
# min             1.000000e+05             12.0000               7.000000
# 25%             3.000000e+05             24.0000               9.150000
# 50%             5.030000e+05             60.0000              10.510000
# 75%             7.010000e+05            240.0000              11.850000
# max             1.618000e+06            360.0000              19.620000
#
#        monthly_income   cibil_score  existing_emis_monthly  \
# count    50000.000000  50000.000000             50000.0000
# mean     50844.940000    699.149760              3066.3620
# std      23874.742237     49.920325              1896.9745
# min      10000.000000    476.000000                 0.0000
# ...

# %%
sns.countplot(data=df_drop, x='loan_type')
plt.title('Count of loan type')
plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot(data=df_drop, x='purpose_of_loan')
plt.title('Count of purpose of loan')
plt.xticks(rotation=45)
plt.show()

# %%
sns.countplot(data=df_drop, x='employment_status')
plt.title('Count of employment status')
plt.xticks(rotation=45)
plt.show()

# %%
# Weekly frequency
df_drop['application_date'] = pd.to_datetime(df_drop['application_date'])
df_drop.set_index('application_date', inplace=True)
weekly_loans = df_drop.resample('W').size().reset_index(name='loan_count')

plt.figure(figsize=(12, 6))
plt.plot(weekly_loans['application_date'], weekly_loans['loan_count'], marker='o')
plt.title('Weekly Loans Taken Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Loans')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
